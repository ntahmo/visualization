# %% [markdown]
# ## Subplots and Combining Visualizations (continuation)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %% [markdown]
# **Using images from the internet**

# %%
# First let’s load our libraries

from PIL import Image # to open images
import requests # to get images from URLs
from io import BytesIO # to store images

# %%
# Then get our image from the internet

# old: response = requests.get('https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png')
# new
url = "https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png"

response = requests.get(
    url,
    headers={"User-Agent": "Mozilla/5.0"})

image_file = BytesIO(response.content)
image = Image.open(image_file)

# %%
# same sample data
x = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100, 90, 120, 50])

# Now make a basic line plot (reusing our data)
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "red")

# Then overlay a new axis (‘ax_image’) on our figure (on top of ‘ax’) to act as a container for our image
ax_image = fig.add_axes([0.1, # x coordinate (ON FIGURE, NOT AXES)
0.11, # y coordinate (ON FIGURE, NOT AXES)
0.15, # image width
0.35]) # image height

# Then add imshow() to prepared image
ax_image.imshow(image)
ax_image.axis('off')
# Out:
# (np.float64(-0.5), np.float64(219.5), np.float64(425.5), np.float64(-0.5))

# %% [markdown]
# **Add other multiple images**

# %%
# Luffy
url = "https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png"
response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
image_file = BytesIO(response.content)
image_1 = Image.open(image_file)

# Zoro
url = "https://upload.wikimedia.org/wikipedia/en/a/a4/Roronoa_Zoro.jpg"
response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
image_file = BytesIO(response.content)
image_2 = Image.open(image_file)

# Nami
url = "https://upload.wikimedia.org/wikipedia/en/f/f8/Nami_face.jpg"
response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
image_file = BytesIO(response.content)
image_3 = Image.open(image_file)

# Usopp
url = "https://upload.wikimedia.org/wikipedia/en/5/53/Usopp.png"
response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
image_file = BytesIO(response.content)
image_4 = Image.open(image_file)

# Sanji
url = "https://upload.wikimedia.org/wikipedia/pt/4/48/Sanji.png"
response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
image_file = BytesIO(response.content)
image_5 = Image.open(image_file)

# --- Sample data ---
x = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100, 90, 120, 50])

# --- Basic line plot ---
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color="red")
ax.set_title("Power Levels of Pirate Crew")
ax.set_ylabel("Power")

# --- Overlay image axes on top of the plot ---
# (coordinates are relative to the figure, not the plot)
# [left, bottom, width, height]

# Luffy
ax_img1 = fig.add_axes([0.10, 0.60, 0.15, 0.35])
ax_img1.imshow(image_1)
ax_img1.axis("off")

# Zoro
ax_img2 = fig.add_axes([0.25, 0.11, 0.15, 0.35])
ax_img2.imshow(image_2)
ax_img2.axis("off")

# Nami
ax_img3 = fig.add_axes([0.40, 0.11, 0.15, 0.35])
ax_img3.imshow(image_3)
ax_img3.axis("off")

# Usopp
ax_img4 = fig.add_axes([0.55, 0.30, 0.15, 0.35])
ax_img4.imshow(image_4)
ax_img4.axis("off")

# Sanji
ax_img5 = fig.add_axes([0.80, 0.11, 0.15, 0.35])
ax_img5.imshow(image_5)
ax_img5.axis("off")

# Saving our visualizations
# Define path
path = "C:/Users/nancy/Downloads/DSI Certificate/visualization/02_activities/assignments/images"
# can be full path or relative path
filename = '/fig1a.png'

plt.savefig(path+filename, dpi=300)
# note that path shouldn't end with / since filename starts with it

plt.show( )

# %% [markdown]
# ## Beyond Matplotlib

# %% [markdown]
# • Learn about other packages to use for data visualization in Python, such as:
#
#        ◦ Seaborn
#
#        ◦ Plotly (for interactive viz)
#
#        ◦ Wordclouds and Venn Diagrams
#
# • Discuss when to use (and when not to use) interactive data visualization

# %% [markdown]
# # 1. Seaborn

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
# Load data
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Basic plot
sns.lineplot(data=tips, # choose our dataset
x='total_bill', # define our x variable
y='tip') # define our y variable
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# **Use premade styles**

# %%
sns.set_style('ticks') # other preset styles like ‘darkgrid’, ‘whitegrid’, ‘dark’, ‘white’, ‘ticks’

# Same plot
sns.lineplot(data=tips, # choose our dataset
x='total_bill', # define our x variable
y='tip') # define our y variable
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# **Add title and axis labels**

# %%
tipgraph = sns.lineplot(data=tips,
x='total_bill',
y='tip')
tipgraph.set(title='Tips vs. Total Bill',
xlabel='Total Bill ($)',
ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %% [markdown]
# **Modify aesthetic elements**

# %%
#change plot size
fig = plt.subplots(figsize=(10, 3)) # scaffold

# change color
tipgraph = sns.lineplot(data=tips,
x='total_bill',
y='tip',
color = 'hotpink',
linestyle = '--',
linewidth = 3,
marker = 'o',
markerfacecolor = 'indigo')

# %% [markdown]
# Why Seaborn over simple Matplotlib? Seaborn makes it very easy to represent multiple variables with different visual elements of our graph

# %%
# Add multiple vars
tipgraph = sns.scatterplot(data=tips, x='total_bill',
                           y='tip', style = 'time', 
                           hue ='day', 
                           palette = ['purple','hotpink','deepskyblue','yellowgreen'])

tipgraph.set(title='Tips vs. Total Bill',
             xlabel='Total Bill ($)',
             ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
# Otherwise, use plot faceted by a categorical var (Pairplot)
sns.pairplot(data = tips,
             hue = 'day')

# %%
# Relplot (relplot also lets us explore specific levels within variables)
daysplot = sns.relplot(data=tips,
                    x="total_bill",
                    y="tip",
                    hue="sex", # within plot categories
                    col="day", # facet groups
                    kind="scatter",
                    col_wrap=2)

# %% [markdown]
# # Plotly

# %%
# Import package and load data
import plotly.graph_objects as go # 'go' is 'graph objects’
x1 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

# %%
# Plot a figure
# scaffold
graph = go.Figure()

# Choose figure type
graph.add_trace(go.Bar(x=x1, y=y1))

# %%
# Making our plot
# Next, update our layout to include titles
graph.update_layout(title="Pirate Scores",
                    xaxis_title="Pirates",
                    yaxis_title="Score")

graph.show()

# %% [markdown]
# Plotly features
#
# • If we hover over the bars on our plot, we get automatic data labels
#
# • If we click and drag over a portion of our plot, we can zoom in
#
#      ◦ Double click to zoom back out
#
# • We can click and drag on our axis to scroll
#
# • In the upper-right menu:
#
#      ◦ Save as PNG
#
#      ◦ Pan/zoom
#
#      ◦ Box/Lasso select

# %%
# Save as HTML
graph.write_html("C:/Users/nancy/Downloads/DSI Certificate/visualization/02_activities/assignments/pirategraph.html")

# %%
# Can customize figure
graph = go.Figure()
graph.add_trace(go.Scatter(x=x1, y=y1, mode='markers', # we want points for a scatter plot
marker=dict(size=15, # point size
            color='hotpink', # point colour
            opacity=1, # point transparency/alpha
            line=dict(width=5, color='purple') # point outline
           )))

graph.update_layout(title='Interactive Pirate Plot',
                    xaxis_title='Pirates',
                    yaxis_title='Scores',
                    width=500, 
                    height=500)

# %% [markdown]
# # Wordclouds and venn diagrams

# %%
# Import the wordcloud package and load our sample dataset of movie quotes
from wordcloud import WordCloud
df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
on_bad_lines='skip')

df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# 3                                         King Kong  movie  1933
# 4                  Snow White and the Seven Dwarves  movie  1937
# ..                                              ...    ...   ...
# 727                                              Us  movie  2019
# 728                        Dragon Ball Super: Broly  movie  2019
# 729                                  Black and Blue  movie  2019
# 730                    Between Two Ferns: The Movie  movie  2019
# 731                   Once Upon a Time in Hollywood  movie  2019
#
# [732 rows x 4 columns]

# %%
# We’ll make a simple word cloud using the ‘quote’ variable
# join all our text from each row from our quote column into a string
text = " ".join(each for each in df.quote)

# generate our wordcloud image
wordcloud = WordCloud(background_color="white",
                     colormap = 'inferno').generate(text)

# use matplotlib syntax to put our image in a figure
fig, ax = plt.subplots(figsize=(7, 3))
ax.imshow(wordcloud, # remember 'imshow' from when we added pictures to our matplotlib axes
interpolation='bilinear') # this line helps smooth our image
ax.axis("off")
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))

# %% [markdown]
# # Making venn diagrams

# %%
# First import the package
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

# Then define our sets
A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])

# %%
# Next, assign our sets to each circle and modify the appearance
diagram = venn2_unweighted([A, B],
                           set_labels = ('Fruits', 'Pies'),
                           set_colors=("blue", "red"),
                           alpha=0.5)

plt.show()

# %%
# Modify (*The numbers in our brackets come from the documentation)
diagram = venn2_unweighted([A, B],
                           set_labels = ('Fruits', 'Pies'),
                           set_colors=("blue", "red"),
                           alpha=0.5)

diagram.get_label_by_id("10").set_text("n".join(A - B))
diagram.get_label_by_id("11").set_text("n".join(A & B))
diagram.get_label_by_id("01").set_text("n".join(B - A))
